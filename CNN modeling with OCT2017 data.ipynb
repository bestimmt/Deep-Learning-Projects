# %% [markdown]
# # CNN Modeling with OCT2017 data

# %% [markdown]
# For more info:
# https://www.nature.com/articles/s41598-023-30853-z#ref-CR20

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#!wget https://data.mendeley.com/public-files/datasets/rscbjbr9sj/files/4935bcd6-c7f7-4244-a119-baaf7175b2d8/file_downloaded

# !wget https://data.mendeley.com/public-files/datasets/rscbjbr9sj/files/5699a1d8-d1b6-45db-bb92-b61051445347/file_downloaded
# Out:
# --2024-01-30 11:26:00--  https://data.mendeley.com/public-files/datasets/rscbjbr9sj/files/5699a1d8-d1b6-45db-bb92-b61051445347/file_downloaded
# Resolving data.mendeley.com (data.mendeley.com)... 162.159.130.86, 162.159.133.86
# Connecting to data.mendeley.com (data.mendeley.com)|162.159.130.86|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://prod-dcd-datasets-public-files-eu-west-1.s3.eu-west-1.amazonaws.com/9cfd5550-a37d-4404-9441-860ee091bc67 [following]
# --2024-01-30 11:26:01--  https://prod-dcd-datasets-public-files-eu-west-1.s3.eu-west-1.amazonaws.com/9cfd5550-a37d-4404-9441-860ee091bc67
# Resolving prod-dcd-datasets-public-files-eu-west-1.s3.eu-west-1.amazonaws.com (prod-dcd-datasets-public-files-eu-west-1.s3.eu-west-1.amazonaws.com)... 52.92.3.218, 3.5.64.51, 3.5.72.214, ...
# Connecting to prod-dcd-datasets-public-files-eu-west-1.s3.eu-west-1.amazonaws.com (prod-dcd-datasets-public-files-eu-west-1.s3.eu-west-1.amazonaws.com)|52.92.3.218|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5793183169 (5.4G) [application/gzip]
# Saving to: ‘file_downloaded’
#
# file_downloaded     100%[===================>]   5.39G  19.9MB/s    in 4m 43s
#
# 2024-01-30 11:30:45 (19.5 MB/s) - ‘file_downloaded’ saved [5793183169/5793183169]

# %%
# !tar -xvf file_downloaded

# %%
#!tar -xzf OCT2017.tar.gz
# Out:
# tar (child): OCT2017.tar.gz: Cannot open: No such file or directory
# tar (child): Error is not recoverable: exiting now
# tar: Child returned status 2
# tar: Error is not recoverable: exiting now

# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.image import imread

# %%
pwd
# Out:
# "/Users/canan/Library/CloudStorage/GoogleDrive-canandulgeroglu@gmail.com/Drive'ım/Colab Notebooks"

# %%
pwd
# Out:
# '/Users/canan/Downloads'

# %%
my_data= 'OCT2017/'

# %%
os.listdir(my_data)
# Out:
# ['.DS_Store', 'test', 'train']

# %%
train_path = my_data+'/train/'
test_path = my_data+'/test/'

# %%
os.listdir(train_path)
# Out:
# ['CNV', '.DS_Store', 'DME', 'DRUSEN', 'NORMAL']

# %%
os.listdir(test_path)
# Out:
# ['CNV', '.DS_Store', 'DME', 'DRUSEN', 'NORMAL']

# %%
os.listdir(train_path+'CNV')[:3]
# Out:
# ['CNV-5557306-155.jpeg', 'CNV-163081-153.jpeg', 'CNV-3537912-28.jpeg']

# %%
len(os.listdir(train_path+'DME'))
# Out:
# 11348

# %%
len(os.listdir(train_path+'CNV'))
# Out:
# 37205

# %%
len(os.listdir(train_path+'NORMAL'))
# Out:
# 26315

# %%
len(os.listdir(train_path+'DRUSEN'))
# Out:
# 8616

# %%
len(os.listdir(test_path+'DME'))
# Out:
# 250

# %%
len(os.listdir(test_path+'CNV'))
# Out:
# 250

# %%
len(os.listdir(test_path+'NORMAL'))
# Out:
# 250

# %%
len(os.listdir(test_path+'DRUSEN'))
# Out:
# 250

# %%
normal_path = train_path+'NORMAL/'+os.listdir(train_path+'NORMAL')[17]

# %%
normal = imread(normal_path)
plt.imshow(normal);

# %%
normal.shape
# Out:
# (496, 768)

# %%
x = []
y = []
for image in os.listdir(test_path+'NORMAL'):

    img = imread(test_path+'NORMAL/'+image)
    d1,d2= img.shape
    x.append(d1)
    y.append(d2)

# %%
shape_list=[]
for image in os.listdir(test_path+'NORMAL'):

    img = imread(test_path+'NORMAL/'+image)
    x= img.shape
    shape_list.append(x)

# %%
shape_list[:10]
# Out:
# [(496, 512),
#  (496, 512),
#  (496, 512),
#  (496, 512),
#  (496, 512),
#  (496, 512),
#  (496, 512),
#  (496, 512),
#  (496, 512),
#  (496, 512)]

# %%
y[:11]
# Out:
# [512, 512, 512, 512, 512, 512, 512, 512, 512, 512, 512]

# %%
np.mean(x)
# Out:
# 496.0

# %%
np.mean(y)
# Out:
# 527.36

# %%
sns.scatterplot(y=x,x=y);

# %%
x = []
y = []
for image in os.listdir(test_path+'DME'):

    img = imread(test_path+'DME/'+image)
    d1,d2= img.shape
    x.append(d1)
    y.append(d2)

# %%
sns.scatterplot(x=x,y=y);

# %%
np.mean(x)
# Out:
# 496.0

# %%
np.mean(y)
# Out:
# 627.712

# %%
shape_list=[]
for image in os.listdir(test_path+'DME'):

    img = imread(test_path+'DME/'+image)
    x= img.shape
    shape_list.append(x)

# %%
shape_list[:10]
# Out:
# [(496, 512),
#  (496, 512),
#  (496, 512),
#  (496, 512),
#  (496, 768),
#  (496, 512),
#  (496, 768),
#  (496, 512),
#  (496, 768),
#  (496, 768)]

# %%
x = []
y = []
for image in os.listdir(test_path+'CNV'):

    img = imread(test_path+'CNV/'+image)
    d1,d2= img.shape
    x.append(d1)
    y.append(d2)

# %%
sns.scatterplot(x=x,y=y);

# %%
y[:10]
# Out:
# [768, 512, 512, 512, 768, 512, 512, 512, 768, 512]

# %%
x
# Out:
# (496, 512)

# %%
np.mean(x)
# Out:
# 496.0

# %%
np.mean(y)
# Out:
# 581.632

# %%
shape_list=[]
for image in os.listdir(test_path+'CNV'):

    img = imread(test_path+'CNV/'+image)
    x= img.shape
    shape_list.append(x)

# %%
shape_list[:10]
# Out:
# [(496, 768),
#  (496, 512),
#  (496, 512),
#  (496, 512),
#  (496, 768),
#  (496, 512),
#  (496, 512),
#  (496, 512),
#  (496, 768),
#  (496, 512)]

# %%
shape_list=[]
for image in os.listdir(test_path+'DRUSEN'):

    img = imread(test_path+'DRUSEN/'+image)
    x= img.shape
    shape_list.append(x)

# %%
shape_list[10:20]
# Out:
# [(496, 768),
#  (496, 512),
#  (496, 512),
#  (496, 512),
#  (496, 512),
#  (496, 512),
#  (496, 512),
#  (496, 512),
#  (496, 512),
#  (496, 768)]

# %%
x = []
y = []
for image in os.listdir(test_path+'DRUSEN'):

    img = imread(test_path+'DRUSEN/'+image)
    d1,d2= img.shape
    x.append(d1)
    y.append(d2)

# %%
sns.scatterplot(x=x,y=y);

# %%
np.mean(x)
# Out:
# 496.0

# %%
np.mean(y)
# Out:
# 550.912

# %% [markdown]
# average x = 496
#
# average y = 571

# %%
normal.max()
# Out:
# 255

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
image_gen = ImageDataGenerator(rotation_range=20, # rotate the image 20 degrees
                               width_shift_range=0.10, # Shift the pic width by a max of 10%
                               height_shift_range=0.10, # Shift the pic height by a max of 10%
                               rescale=1/255, # Rescale the image by normalzing it.
                               shear_range=0.1, # Shear means cutting away part of the image (max 10%)
                               zoom_range=0.1, # Zoom in by 10% max
                               horizontal_flip=True, # Allo horizontal flipping
                               fill_mode='nearest' # Fill in missing pixels with the nearest filled value
                              )

# %%
drusen_path = train_path+'DRUSEN/'+os.listdir(train_path+'DRUSEN')[11]

# %%
drusen = imread(drusen_path)
plt.imshow(drusen);

# %%
drusen = imread(drusen_path)
plt.imshow(drusen);

# %%
drusen.shape
# Out:
# (496, 768)

# %%
plt.imshow(image_gen.random_transform(drusen));
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-91-26d0cffd9df0> in <cell line: 1>()
# ----> 1 plt.imshow(image_gen.random_transform(drusen));
#
# /usr/local/lib/python3.10/dist-packages/keras/src/preprocessing/image.py in random_transform(self, x, seed)
#    2057         """
#    2058         params = self.get_random_transform(x.shape, seed)
# -> 2059         return self.apply_transform(x, params)
#    2060
#    2061     def fit(self, x, augment=False, rounds=1, seed=None):
#
# /usr/local/lib/python3.10/dist-packages/keras/src/preprocessing/image.py in apply_transform(self, x, transform_parameters)
#    2010         img_channel_axis = self.channel_axis - 1
#    2011
# -> 2012         x = apply_affine_transform(
#    2013             x,
#    2014             transform_parameters.get("theta", 0),
#
# /usr/local/lib/python3.10/dist-packages/keras/src/preprocessing/image.py in apply_affine_transform(x, theta, tx, ty, shear, zx, zy, row_axis, col_axis, channel_axis, fill_mode, cval, order)
#    2544
#    2545     if x.ndim != 3:
# -> 2546         raise ValueError("Input arrays must be multi-channel 2D images.")
#    2547     if channel_axis not in [0, 2]:
#    2548         raise ValueError(
#
# ValueError: Input arrays must be multi-channel 2D images.

# %%
drusen.ndim
# Out:
# 2

# %%
if drusen.ndim != 3:
    drusen = np.expand_dims(drusen, axis=-1)

# %%
drusen.shape
# Out:
# (496, 768, 1)

# %%
plt.imshow(image_gen.random_transform(drusen));

# %%
image_gen.flow_from_directory(train_path)
# Out:
# Found 83484 images belonging to 4 classes.

# %%
image_gen.flow_from_directory(test_path)
# Out:
# Found 1000 images belonging to 4 classes.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import cv2
import os

import warnings
warnings.filterwarnings('ignore')

from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, BatchNormalization, Conv2D, Dense, Dropout, Flatten, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers.legacy import Adam
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

# %%
image_shape = (224,224,1)

# %%
model = Sequential()
model.add(Conv2D(filters=64, kernel_size=(3,3),input_shape=image_shape, activation='relu',))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(filters=32, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(filters=32, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())


model.add(Dense(64, activation='relu'))


model.add(Dense(4, activation='softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 298, 298, 64)      640
#
#  max_pooling2d (MaxPooling2  (None, 149, 149, 64)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 147, 147, 32)      18464
#
#  max_pooling2d_1 (MaxPoolin  (None, 73, 73, 32)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 71, 71, 32)        9248
#
#  max_pooling2d_2 (MaxPoolin  (None, 35, 35, 32)        0
#  g2D)
#
#  flatten (Flatten)           (None, 39200)             0
#
#  dense (Dense)               (None, 64)                2508864
#
#  dense_1 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 2537476 (9.68 MB)
# Trainable params: 2537476 (9.68 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
early_stop = EarlyStopping(monitor='val_loss',patience=5)
batch_size = 64

# %%
train_image_gen = image_gen.flow_from_directory(train_path,
                                               target_size=(224,224),
                                               color_mode='grayscale',
                                               batch_size=batch_size,
                                               class_mode='categorical',
                                               shuffle=True)
# Out:
# Found 83484 images belonging to 4 classes.

# %%
test_image_gen = image_gen.flow_from_directory(test_path,
                                               target_size=(224,224),
                                               color_mode='grayscale',
                                               batch_size=batch_size,
                                               class_mode='categorical',
                                               shuffle=False)
# Out:
# Found 1000 images belonging to 4 classes.

# %%
labels = {value: key for key, value in train_image_gen.class_indices.items()}

print("Label Mappings for classes present in the training and validation datasets\n")
for key, value in labels.items():
    print(f"{key} : {value}")
# Out:
# Label Mappings for classes present in the training and validation datasets
#
# 0 : CNV
# 1 : DME
# 2 : DRUSEN
# 3 : NORMAL

# %%
results = model.fit(train_image_gen,epochs=10,
                    validation_data=test_image_gen,
                    callbacks=[early_stop])
# Out:
# Epoch 1/10
# 2609/2609 [==============================] - 915s 348ms/step - loss: 0.7229 - accuracy: 0.7224 - val_loss: 0.7201 - val_accuracy: 0.6960
# Epoch 2/10
# 2609/2609 [==============================] - 844s 324ms/step - loss: 0.5191 - accuracy: 0.8089 - val_loss: 0.5192 - val_accuracy: 0.7910
# Epoch 3/10
# 2609/2609 [==============================] - 817s 313ms/step - loss: 0.4525 - accuracy: 0.8339 - val_loss: 0.3535 - val_accuracy: 0.8750
# Epoch 4/10
# 2609/2609 [==============================] - 819s 314ms/step - loss: 0.3969 - accuracy: 0.8578 - val_loss: 0.2658 - val_accuracy: 0.9080
# Epoch 5/10
# 2609/2609 [==============================] - 794s 304ms/step - loss: 0.3525 - accuracy: 0.8757 - val_loss: 0.2176 - val_accuracy: 0.9370
# Epoch 6/10
# 2609/2609 [==============================] - 809s 310ms/step - loss: 0.3244 - accuracy: 0.8847 - val_loss: 0.1795 - val_accuracy: 0.9510
# Epoch 7/10
# 2609/2609 [==============================] - 807s 309ms/step - loss: 0.3031 - accuracy: 0.8927 - val_loss: 0.1453 - val_accuracy: 0.9540
# Epoch 8/10
# 2609/2609 [==============================] - 794s 304ms/step - loss: 0.2907 - accuracy: 0.8983 - val_loss: 0.2319 - val_accuracy: 0.9110
# Epoch 9/10
# 2609/2609 [==============================] - 795s 305ms/step - loss: 0.2800 - accuracy: 0.9015 - val_loss: 0.2167 - val_accuracy: 0.9190
# Epoch 10/10
# 2609/2609 [==============================] - 803s 308ms/step - loss: 0.2704 - accuracy: 0.9048 - val_loss: 0.1840 - val_accuracy: 0.9360

# %%
summary = pd.DataFrame(model.history.history)
summary
# Out:
#        loss  accuracy  val_loss  val_accuracy
# 0  0.722883  0.722366  0.720128         0.696
# 1  0.519079  0.808874  0.519160         0.791
# 2  0.452464  0.833944  0.353463         0.875
# 3  0.396862  0.857793  0.265788         0.908
# 4  0.352533  0.875677  0.217647         0.937
# 5  0.324370  0.884661  0.179494         0.951
# 6  0.303124  0.892746  0.145259         0.954
# 7  0.290706  0.898280  0.231894         0.911
# 8  0.279987  0.901550  0.216662         0.919
# 9  0.270413  0.904844  0.183950         0.936

# %%
plt.figure(figsize=(10,6))
plt.plot(summary.loss, label="loss")
plt.plot(summary.val_loss, label="val_loss")
plt.legend(loc="upper right")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.plot(summary.accuracy, label="accuracy")
plt.plot(summary.val_accuracy, label="val_accuracy")
plt.legend(loc="upper left")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.show()

# %%
model = Sequential()
model.add(Conv2D(filters=64, kernel_size=(5,5),input_shape=image_shape, activation='relu',))

model.add(Conv2D(filters=64, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization())

model.add(Conv2D(filters=64, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))

#model.add(Conv2D(filters=64, kernel_size=(3,3), activation='relu'))
#model.add(MaxPooling2D(pool_size=(2, 2)))
#model.add(BatchNormalization())

model.add(Conv2D(filters=128, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Conv2D(filters=128, kernel_size=(3,3), activation='relu'))
model.add(Dropout(0.2))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(filters=256, kernel_size=(3,3), activation='relu'))
#model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())

model.add(Dense(128, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Dense(4, activation='softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
#model.summary()
# Out:
# Model: "sequential_21"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_150 (Conv2D)         (None, 220, 220, 64)      1664
#
#  conv2d_151 (Conv2D)         (None, 218, 218, 64)      36928
#
#  max_pooling2d_73 (MaxPooli  (None, 109, 109, 64)      0
#  ng2D)
#
#  batch_normalization_88 (Ba  (None, 109, 109, 64)      256
#  tchNormalization)
#
#  conv2d_152 (Conv2D)         (None, 107, 107, 64)      36928
#
#  max_pooling2d_74 (MaxPooli  (None, 53, 53, 64)        0
#  ng2D)
#
#  batch_normalization_89 (Ba  (None, 53, 53, 64)        256
#  tchNormalization)
#
#  dropout_83 (Dropout)        (None, 53, 53, 64)        0
#
#  conv2d_153 (Conv2D)         (None, 51, 51, 128)       73856
#
#  max_pooling2d_75 (MaxPooli  (None, 25, 25, 128)       0
#  ng2D)
#
#  batch_normalization_90 (Ba  (None, 25, 25, 128)       512
#  tchNormalization)
#
#  dropout_84 (Dropout)        (None, 25, 25, 128)       0
#
#  conv2d_154 (Conv2D)         (None, 23, 23, 128)       147584
#
#  dropout_85 (Dropout)        (None, 23, 23, 128)       0
#
#  max_pooling2d_76 (MaxPooli  (None, 11, 11, 128)       0
#  ng2D)
#
#  conv2d_155 (Conv2D)         (None, 9, 9, 256)         295168
#
#  flatten_21 (Flatten)        (None, 20736)             0
#
#  dense_42 (Dense)            (None, 128)               2654336
#
#  batch_normalization_91 (Ba  (None, 128)               512
#  tchNormalization)
#
#  dropout_86 (Dropout)        (None, 128)               0
#
#  dense_43 (Dense)            (None, 4)                 516
#
# =================================================================
# Total params: 3248516 (12.39 MB)
# Trainable params: 3247748 (12.39 MB)
# Non-trainable params: 768 (3.00 KB)
# _________________________________________________________________

# %%
model.summary()
# Out:
# Model: "sequential_22"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_156 (Conv2D)         (None, 222, 222, 64)      640
#
#  max_pooling2d_77 (MaxPooli  (None, 111, 111, 64)      0
#  ng2D)
#
#  conv2d_157 (Conv2D)         (None, 109, 109, 32)      18464
#
#  max_pooling2d_78 (MaxPooli  (None, 54, 54, 32)        0
#  ng2D)
#
#  conv2d_158 (Conv2D)         (None, 52, 52, 32)        9248
#
#  max_pooling2d_79 (MaxPooli  (None, 26, 26, 32)        0
#  ng2D)
#
#  flatten_22 (Flatten)        (None, 21632)             0
#
#  dense_44 (Dense)            (None, 64)                1384512
#
#  dense_45 (Dense)            (None, 4)                 260
#
# =================================================================
# Total params: 1413124 (5.39 MB)
# Trainable params: 1413124 (5.39 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
results = model.fit(train_image_gen,epochs=20,
                    validation_data=test_image_gen,
                    callbacks=[early_stop])
# Out:
# Epoch 1/20
# 1305/1305 [==============================] - 1205s 923ms/step - loss: 0.7477 - accuracy: 0.7111 - val_loss: 0.7970 - val_accuracy: 0.6680
# Epoch 2/20
# 1305/1305 [==============================] - 1303s 998ms/step - loss: 0.4854 - accuracy: 0.8233 - val_loss: 0.4003 - val_accuracy: 0.8450
# Epoch 3/20
# 1305/1305 [==============================] - 1296s 993ms/step - loss: 0.3913 - accuracy: 0.8604 - val_loss: 0.2169 - val_accuracy: 0.9250
# Epoch 4/20
# 1305/1305 [==============================] - 1311s 1s/step - loss: 0.3388 - accuracy: 0.8792 - val_loss: 0.2050 - val_accuracy: 0.9270
# Epoch 5/20
# 1305/1305 [==============================] - 1255s 962ms/step - loss: 0.3074 - accuracy: 0.8909 - val_loss: 0.1396 - val_accuracy: 0.9580
# Epoch 6/20
# 1305/1305 [==============================] - 1228s 941ms/step - loss: 0.2825 - accuracy: 0.9006 - val_loss: 0.1913 - val_accuracy: 0.9400
# Epoch 7/20
# 1305/1305 [==============================] - 1224s 938ms/step - loss: 0.2691 - accuracy: 0.9062 - val_loss: 0.1048 - val_accuracy: 0.9640
# Epoch 8/20
# 1305/1305 [==============================] - 1211s 928ms/step - loss: 0.2554 - accuracy: 0.9102 - val_loss: 0.1457 - val_accuracy: 0.9470
# Epoch 9/20
# 1305/1305 [==============================] - 1210s 927ms/step - loss: 0.2443 - accuracy: 0.9145 - val_loss: 0.1148 - val_accuracy: 0.9560
# Epoch 10/20
# 1305/1305 [==============================] - 4078s 3s/step - loss: 0.2375 - accuracy: 0.9168 - val_loss: 0.0989 - val_accuracy: 0.9690
# Epoch 11/20
# 1305/1305 [==============================] - 2383s 2s/step - loss: 0.2289 - accuracy: 0.9209 - val_loss: 0.0938 - val_accuracy: 0.9680
# Epoch 12/20
# 1305/1305 [==============================] - 1355s 1s/step - loss: 0.2259 - accuracy: 0.9211 - val_loss: 0.0993 - val_accuracy: 0.9660
# Epoch 13/20
# 1305/1305 [==============================] - 1448s 1s/step - loss: 0.2206 - accuracy: 0.9234 - val_loss: 0.1734 - val_accuracy: 0.9450
# Epoch 14/20
# 1305/1305 [==============================] - 2272s 2s/step - loss: 0.2141 - accuracy: 0.9256 - val_loss: 0.0876 - val_accuracy: 0.9680
# Epoch 15/20
# 1305/1305 [==============================] - 1365s 1s/step - loss: 0.2131 - accuracy: 0.9265 - val_loss: 0.1024 - val_accuracy: 0.9630
# Epoch 16/20
# 1305/1305 [==============================] - 1377s 1s/step - loss: 0.2097 - accuracy: 0.9273 - val_loss: 0.1075 - val_accuracy: 0.9630
# Epoch 17/20
# 1305/1305 [==============================] - 2755s 2s/step - loss: 0.2083 - accuracy: 0.9280 - val_loss: 0.1581 - val_accuracy: 0.9410
# Epoch 18/20
# 1305/1305 [==============================] - 1216s 931ms/step - loss: 0.2019 - accuracy: 0.9300 - val_loss: 0.1340 - val_accuracy: 0.9470
# Epoch 19/20
# 1305/1305 [==============================] - 1125s 862ms/step - loss: 0.1990 - accuracy: 0.9301 - val_loss: 0.1201 - val_accuracy: 0.9590

# %%
summary1 = pd.DataFrame(model.history.history)
summary1
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 0   0.747741  0.711130  0.797027         0.668
# 1   0.485374  0.823260  0.400334         0.845
# 2   0.391255  0.860392  0.216908         0.925
# 3   0.338792  0.879174  0.205004         0.927
# 4   0.307368  0.890949  0.139598         0.958
# 5   0.282458  0.900556  0.191278         0.940
# 6   0.269142  0.906198  0.104780         0.964
# 7   0.255361  0.910198  0.145656         0.947
# 8   0.244300  0.914463  0.114806         0.956
# 9   0.237536  0.916798  0.098856         0.969
# 10  0.228859  0.920859  0.093829         0.968
# 11  0.225913  0.921099  0.099320         0.966
# 12  0.220562  0.923363  0.173407         0.945
# 13  0.214088  0.925626  0.087563         0.968
# 14  0.213095  0.926489  0.102365         0.963
# 15  0.209703  0.927339  0.107499         0.963
# 16  0.208338  0.928010  0.158056         0.941
# 17  0.201863  0.929987  0.134010         0.947
# 18  0.198968  0.930082  0.120122         0.959

# %%
plt.figure(figsize=(10,6))
plt.plot(summary1.loss, label="loss")
plt.plot(summary1.val_loss, label="val_loss")
plt.legend(loc="upper right")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.plot(summary1.accuracy, label="accuracy")
plt.plot(summary1.val_accuracy, label="val_accuracy")
plt.legend(loc="upper left")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.show()

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
model.evaluate(test_image_gen)
# Out:
# 32/32 [==============================] - 4s 109ms/step - loss: 0.1223 - accuracy: 0.9580
# [0.1222810298204422, 0.9580000042915344]

# %%
pred_probabilities = model.predict(test_image_gen)
predictions = pred_probabilities > 0.5
# Out:
# 32/32 [==============================] - 4s 108ms/step

# %%
y_pred = np.argmax(pred_probabilities, axis=1)
y_true = test_image_gen.classes

# %%
print(classification_report(y_true, y_pred, target_names=labels.values()))
# Out:
#               precision    recall  f1-score   support
#
#          CNV       0.86      1.00      0.93       250
#          DME       0.99      0.98      0.99       250
#       DRUSEN       1.00      0.85      0.92       250
#       NORMAL       1.00      1.00      1.00       250
#
#     accuracy                           0.96      1000
#    macro avg       0.96      0.96      0.96      1000
# weighted avg       0.96      0.96      0.96      1000

# %%
cm = confusion_matrix(y_true, y_pred)
cm
# Out:
# array([[249,   1,   0,   0],
#        [  3, 246,   0,   1],
#        [ 36,   1, 213,   0],
#        [  0,   0,   1, 249]])

# %%
cm = confusion_matrix(y_true, y_pred)
# Confusion matrix i görselleştirin
plt.figure (figsize= (10, 10))
plt.imshow (cm, cmap='Greens')
plt.colorbar ()

# Her hücreye etiket veya yüzde yazın
for i in range (cm.shape [0]):
  for j in range (cm.shape [1]):
    plt.text (j, i, cm [i, j], ha='center', va='center', color='black')

plt.show ()

# %% [markdown]
# 0 : CNV (Choroidal Neovascularisation)
#
# 1 : DME (Diabetic Macular Edema)
#
# 2 : DRUSEN
#
# 3 : NORMAL

# %% [markdown]
# **___________________________________________________________________________________________________________**
